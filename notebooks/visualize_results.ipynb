# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os


# Get the parent directory of the notebook and append `src/` to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.plots import visualize_model_metrics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
label_a, path_a= ('kNN', os.path.abspath(os.path.join(os.getcwd(), "..",'models','aggregated','kNN_default','results')))
label_b, path_b= ('XGBRegressor', os.path.abspath(os.path.join(os.getcwd(), "..",'models','aggregated','XGBRegressor_default','results')))

(times, mae_ev_a, mae_energy_a, avg_ev, avg_energy) = visualize_model_metrics.load_method_results(path_a)
(_,    mae_ev_b, mae_energy_b, _,        _)         = visualize_model_metrics.load_method_results(path_b)
times = [str(t) for t in times]

visualize_model_metrics.plot_mae_vs_time(times, mae_energy_a, mae_energy_b, label_a, label_b)
visualize_model_metrics.plot_mae_vs_time(times, mae_ev_a, mae_ev_b, label_a, label_b)

# %%
visualize_model_metrics.plot(path_a)

# %%
visualize_model_metrics.plot(path_b)
